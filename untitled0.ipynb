# %% [markdown]
# <a href="https://colab.research.google.com/github/zephyring/Camille/blob/add-license-1/untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -U kaleido
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 8.1 MB/s eta 0:00:00
# ...

# %%
pip install pygwalker
# Out:
#   File "<ipython-input-6-6d824cc681d9>", line 1
#     pip install pygwalker
#         ^
# SyntaxError: invalid syntax

# %%
import pandas as pd


df = pd.read_csv('/content/sample_data/california_housing_test.csv')
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
# prompt: using plotly to do EDA on df

import plotly.express as px
import plotly.graph_objects as go

print("start")
# Example: Histogram of housing median age
fig = px.histogram(df, x="housing_median_age")
display(fig.to_image())

print("end")
# Out:
# start
# ...
